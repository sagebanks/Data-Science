# %% [markdown]
# <a href="https://colab.research.google.com/github/sagebanks/Data-Science/blob/main/Banks_Stats_22_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f5adffccf40>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
#imported data about popular cereal brands in america

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
#charted the data of all the cereal and nutritional facts that come with it

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %%
#the mean sugar ammount in the ceral

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
#the callories ans sugar compared to eachother

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %%
#amount of sugar and calories ploted in dot graph

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
#fat and calories ploted in graph

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
#sugar and carbs ploted

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
#sugar and vitamins ploted

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
#line of best fit in a sugar and calories graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 4584.769911338688

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 417123.5170869627 -10.0 -10.0
# 398874.46867223 -10.0 -7.777777777777778
# 381119.2474179912 -10.0 -5.555555555555555
# 363857.8533242462 -10.0 -3.333333333333333
# 347090.286390995 -10.0 -1.1111111111111107
# 330816.5466182377 -10.0 1.1111111111111107
# 315036.6340059742 -10.0 3.333333333333334
# 299750.54855420446 -10.0 5.555555555555557
# 284958.2902629285 -10.0 7.777777777777779
# 270659.8591321465 -10.0 10.0
# 309107.10709409986 -7.777777777777778 -10.0
# 293327.1944818362 -7.777777777777778 -7.777777777777778
# 278041.1090300666 -7.777777777777778 -5.555555555555555
# 263248.8507387907 -7.777777777777778 -3.333333333333333
# 248950.4196080087 -7.777777777777778 -1.1111111111111107
# 235145.81563772046 -7.777777777777778 1.1111111111111107
# 221835.03882792604 -7.777777777777778 3.333333333333334
# 209018.0891786255 -7.777777777777778 5.555555555555557
# 196694.9666898187 -7.777777777777778 7.777777777777779
# 184865.6713615058 -7.777777777777778 10.0
# 217719.57087296783 -5.555555555555555 -10.0
# 204408.79406317344 -5.555555555555555 -7.777777777777778
# 191591.8444138729 -5.555555555555555 -5.555555555555555
# 179268.72192506614 -5.555555555555555 -3.333333333333333
# 167439.4265967532 -5.555555555555555 -1.1111111111111107
# 156103.95842893416 -5.555555555555555 1.1111111111111107
# 145262.31742160887 -5.555555555555555 3.333333333333334
# 134914.50357477742 -5.555555555555555 5.555555555555557
# 125060.51688843984 -5.555555555555555 7.777777777777779
# 115700.35736259607 -5.555555555555555 10.0
# 142960.90842356675 -3.333333333333333 -10.0
# 132119.26741624152 -3.333333333333333 -7.777777777777778
# 121771.45356941008 -3.333333333333333 -5.555555555555555
# 111917.46688307247 -3.333333333333333 -3.333333333333333
# 102557.3073572287 -3.333333333333333 -1.1111111111111107
# 93690.97499187877 -3.333333333333333 1.1111111111111107
# 85318.46978702262 -3.333333333333333 3.333333333333334
# 77439.79174266032 -3.333333333333333 5.555555555555557
# 70054.94085879186 -3.333333333333333 7.777777777777779
# 63163.917135417236 -3.333333333333333 10.0
# 84831.11974589662 -1.1111111111111107 -10.0
# 76458.6145410405 -1.1111111111111107 -7.777777777777778
# 68579.9364966782 -1.1111111111111107 -5.555555555555555
# 61195.08561280972 -1.1111111111111107 -3.333333333333333
# 54304.061889435085 -1.1111111111111107 -1.1111111111111107
# 47906.865326554274 -1.1111111111111107 1.1111111111111107
# 42003.49592416729 -1.1111111111111107 3.333333333333334
# 36593.953682274136 -1.1111111111111107 5.555555555555557
# 31678.238600874804 -1.1111111111111107 7.777777777777779
# 27256.3506799693 -1.1111111111111107 10.0
# 43330.20483995739 1.1111111111111107 -10.0
# 37426.83543757041 1.1111111111111107 -7.777777777777778
# 32017.293195677245 1.1111111111111107 -5.555555555555555
# 27101.57811427791 1.1111111111111107 -3.333333333333333
# 22679.690193372404 1.1111111111111107 -1.1111111111111107
# 18751.62943296073 1.1111111111111107 1.1111111111111107
# 15317.395833042878 1.1111111111111107 3.333333333333334
# 12376.989393618853 1.1111111111111107 5.555555555555557
# 9930.410114688659 1.1111111111111107 7.777777777777779
# 7977.65799625229 1.1111111111111107 10.0
# 18458.163705749055 3.333333333333334 -10.0
# 15023.930105831207 3.333333333333334 -7.777777777777778
# 12083.523666407185 3.333333333333334 -5.555555555555555
# 9636.944387476986 3.333333333333334 -3.333333333333333
# 7684.192269040622 3.333333333333334 -1.1111111111111107
# 6225.26731109808 3.333333333333334 1.1111111111111107
# 5260.169513649367 3.333333333333334 3.333333333333334
# 4788.89887669448 3.333333333333334 5.555555555555557
# 4811.4554002334235 3.333333333333334 7.777777777777779
# 5327.83908426619 3.333333333333334 10.0
# 10214.99634327165 5.555555555555557 -10.0
# 9249.89854582294 5.555555555555557 -7.777777777777778
# 8778.627908868055 5.555555555555557 -5.555555555555555
# 8801.184432406995 5.555555555555557 -3.333333333333333
# 9317.568116439767 5.555555555555557 -1.1111111111111107
# 10327.778960966361 5.555555555555557 1.1111111111111107
# 11831.816965986787 5.555555555555557 3.333333333333334
# 13829.682131501038 5.555555555555557 5.555555555555557
# 16321.374457509117 5.555555555555557 7.777777777777779
# 19306.89394401102 5.555555555555557 10.0
# 18600.702752525165 7.777777777777779 -10.0
# 20104.74075754559 7.777777777777779 -7.777777777777778
# 22102.605923059837 7.777777777777779 -5.555555555555555
# 24594.298249067913 7.777777777777779 -3.333333333333333
# 27579.817735569817 7.777777777777779 -1.1111111111111107
# 31059.164382565556 7.777777777777779 1.1111111111111107
# 35032.33819005511 7.777777777777779 3.333333333333334
# 39499.33915803851 7.777777777777779 5.555555555555557
# 44460.1672865157 7.777777777777779 7.777777777777779
# 49914.822575486745 7.777777777777779 10.0
# 43615.28293350959 10.0 -10.0
# 47588.45674099916 10.0 -7.777777777777778
# 52055.457708982525 10.0 -5.555555555555555
# 57016.28583745974 10.0 -3.333333333333333
# 62470.94112643077 10.0 -1.1111111111111107
# 68419.42357589565 10.0 1.1111111111111107
# 74861.73318585433 10.0 3.333333333333334
# 81797.86995630687 10.0 5.555555555555557
# 89227.83388725319 10.0 7.777777777777779
# 97151.62497869339 10.0 10.0

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
